# %% [markdown]
# <a href="https://colab.research.google.com/github/IshtiSikder/Optimal-appointment-scheduling-for-Mayo-Clinic/blob/main/Override_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Hardcoded. Can not process more than 22 influx !

# %%
#Install gurobi
# !pip install gurobipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gurobipy in /usr/local/lib/python3.7/dist-packages (10.0.0)

# %%
import pandas as pd
#for entering and working with data

import numpy as np


import sys
from numpy import linalg as la
import gurobipy as gp

from gurobipy import*

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/GOOGLE_COLAB/MAYO'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/GOOGLE_COLAB/MAYO

# %%
#REMOVE LATER################################################################

data_test = pd.read_excel("data.xlsx", sheet_name = "influx")
data_test = data_test.set_index('Date')
data_test = data_test.astype(int)
data_test.index = data_test.index.astype(int)
data_test.columns = data_test.columns.astype(int)
data_test = data_test.drop(data_test.index[60:])

#REMOVE LATER################################################################

# %%
data = pd.read_excel("data.xlsx", sheet_name = "influx")
data = data.set_index('Date')
data = data.astype(int)
data.index = data.index.astype(int)
data.columns = data.columns.astype(int)
data = data.drop(data.index[:60])
data

#REMOVE LATER################################################################

no_std = float(input('Standard deviation:'))
new_row = []
for col in data_test.columns:
  new_row.append(int(round(round(data_test[col].mean(),0) + no_std*data_test[col].std(),0)))

data.loc[82] = new_row

data

#REMOVE LATER################################################################
# Out:
# Standard deviation:1
#       30   60   120  180  240  300  360
# Date
# 61     11    7    9    6    2    0    0
# 62     15    7    4    4    3    0    3
# 63     18    6    5    6    2    0    3
# 64     15    5   12    9    3    0    4
# 65      5   10    5    8    4    0    2
# 66     16    6   10    9    3    0    1
# 67     15    8    5    2    1    0    1
# 68     17    7   10    5    8    0    0
# 69     14   13    8    6    7    0    2
# 70     17    8    6    2    4    0    2
# 71     23   11   12    9    6    0    0
# 72     21   10   11    6    2    0    4
# 73     27   10   13   10    6    0    3
# 74     15   11   10   12    2    0    0
# 75     31    8    7    5    2    0    3
# 76     14   12    6    4    2    0    1
# 77     22   11    7    4    5    0    2
# 78     16   10    5    5    5    0    2
# 79     15    8    5   11    3    0    3
# 80     24   10    4    8    4    0    1
# 81     17    5    8    5    5    0    1
# 82     25   11   10   11    7    2    2

# %%
#CHANGE LATER######################################################################

tmpl = pd.read_excel('ORIGINAL/std={}.xlsx'.format(no_std),index_col=[0])
tmpl = tmpl.astype(int)
tmpl.index = tmpl.index.astype(int)
tmpl.columns = tmpl.columns.astype(int)

#CHANGE LATER######################################################################

# %%
tmpl
# Out:
#     30   60   120  180  240  300  360
# 1     0    0    1    0    3    0    0
# 2     0    0    0    0    0    0    2
# 3     0    0    3    0    0    0    0
# 4     2    1    0    0    0    0    0
# 5     0    0    0    0    0    2    0
# 6     0    0    0    0    0    0    0
# 7     0    2    0    0    0    0    0
# 8     1    0    0    0    0    0    0
# 9     0    0    0    1    0    0    0
# 10    0    0    0    1    0    0    0
# 11    5    0    0    0    0    0    0
# 12    0    0    0    0    0    0    0
# 13    3    2    0    0    0    0    0
# 14    0    0    0    0    0    0    0
# 15    1    1    1    0    0    0    0
# 16    0    0    0    0    0    0    0
# 17    5    1    0    0    0    0    0
# 18    0    0    0    0    0    0    0
# 19    0    0    0    6    0    0    0
# 20    0    0    0    0    0    0    0
# 21    0    0    2    0    0    0    0
# 22    1    0    0    0    0    0    0
# 23    1    0    0    0    0    0    0
# 24    0    0    0    0    1    0    0
# 25    0    0    0    0    3    0    0
# 26    1    0    0    1    0    0    0
# 27    0    0    0    0    0    0    0
# 28    0    0    0    1    0    0    0
# 29    0    1    0    1    0    0    0
# 30    0    0    0    0    0    0    0
# 31    0    3    3    0    0    0    0
# 32    0    0    0    0    0    0    0
# 33    1    0    0    0    0    0    0
# 34    0    0    0    0    0    0    0
# 35    2    0    0    0    0    0    0
# 36    2    0    0    0    0    0    0
# 37    0    0    0    0    0    0    0
# 38    0    0    0    0    0    0    0
# 39    0    0    0    0    0    0    0
# 40    0    0    0    0    0    0    0
# 40   25   11   10   11    7    2    2

# %%
data = data.fillna(0)
tmpl = tmpl.fillna(0)

data = data.values
tmpl = tmpl.values  

                    
final=[]

T = list(range(1,41))
    #I = { 30, 60, 120, 180, 240, 300, 360 }
    
I = { 30, 60, 120, 180, 240, 300, 360 }

   
x = {
     (i, t) : 0
     for i in I for t in T
    }
    
for i in I:
    for t in T: 
        if t < np.size(tmpl,0):
            if i == 30:
                x[i,t] = int(tmpl[t-1,0])
            else:
                x[i,t] = int(tmpl[t-1,int(i/60)])

# %%
e = gp.Env(empty=True)
e.setParam('WLSACCESSID', '6cdf9fc0-6a35-4a0a-be53-071d5d3404ab')
e.setParam('WLSSECRET', 'ccd4784b-8277-414a-b1bd-700b12ef2632')
e.setParam('LICENSEID',870370)
e.start()
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 870370
# Academic license - for non-commercial use only - registered to isikder@ncsu.edu
# <gurobipy.Env, Parameter changes: WLSAccessID=(user-defined), WLSSecret=(user-defined), LicenseID=870370>

# %%
# %cd '/content/drive/MyDrive/GOOGLE_COLAB/MAYO/OVERRIDE_CODES/org'

slot = 15
         
for count in range(np.size(data,0)):
#for count in range(12,13):
    count_y=0
    count_z=0
    count_w=0
    count_beta=0
    count_asg=0
    
    P = {i : 0
         for i in I
         }

    for i in I:
        if i == 30:
            P[i] = data[count,0]
        else:
            P[i] = data[count, int(i/60)]

    #print(P)

    # parameters
    #L1 = 200
    #LL = 100
    #L2 = 2
    #L3 = 4


    # Start building chemo model 
    Chemo = gp.Model("Chemo Scheduling")

    aux_idx_y = {
           (i,ii,t,j) for i in I for ii in I for t in T for j in range(int(x[ii,t])) if i <= ii
        }

    y = Chemo.addVars(aux_idx_y, vtype=GRB.BINARY, name='y')

    aux_idx_z = {
        (i,ii,t,j) for i in I for ii in I for t in T for j in range(int(x[ii,t])) if i > ii
        }

    aux_idx_w = {
        (i,iii,t,j) for i in I for iii in I for t in T for j in range(int(x[iii,t])) if i > iii
        }
  
    aux_idx_v = {
            (i,ii,iii,t,j1,j2) for i in I for ii in I for iii in I for t in T if t + ((ii+iii)/slot) in T
            for j1 in range(int(x[ii,t])) for j2 in range(int(x[iii,t+(ii/slot)]))
            if ii < i and iii < i and ii + iii >= i
        }
  
    aux_idx_b = {
            (i,iii,ii,t,j) for i in I for iii in I for ii in I for t in T for j in range(int(x[ii,t]))
            if i < ii and iii < ii and ii >= i + iii
        }
    b = Chemo.addVars(aux_idx_b, vtype=GRB.BINARY, name='beta')

    z = Chemo.addVars(aux_idx_z, vtype=GRB.BINARY, name='z')

    w = Chemo.addVars(aux_idx_w, vtype=GRB.BINARY, name='w')

    v = Chemo.addVars(aux_idx_v, vtype=GRB.INTEGER, lb = 0, name='v')

    u = Chemo.addVars(I, T, vtype=GRB.INTEGER, lb = 0, name='u')

    q = Chemo.addVars(I, vtype=GRB.INTEGER, lb = 0, name='q')

    a = Chemo.addVars(I, vtype=GRB.INTEGER, lb = 0, name='a')

    cons1 = Chemo.addConstrs(
        v[i,ii,iii,t,j1,j2] <= z[i,ii,t,j1] for (i,ii,iii,t,j1,j2) in aux_idx_v
        )

    cons2 = Chemo.addConstrs(
        v[i,ii,iii,t,j1,j2] <= w[i,iii,t + int(ii/slot),j2] for (i,ii,iii,t,j1,j2) in aux_idx_v
        )

    cons3 = Chemo.addConstrs(
        v[i,ii,iii,t,j1,j2] >= z[i,ii,t,j1] + w[i,iii,t + int(ii/slot),j2] - 1 for (i,ii,iii,t,j1,j2) in aux_idx_v
        )

    cons4 = Chemo.addConstrs(
        v.sum(i,ii,'*',t,j1,'*') <= 1 for (i,ii,t,j1) in aux_idx_z
        )
   
    for ii in I:
        for t in T:
            for j in range(int(x[ii,t])):
                expr = LinExpr(0.0)
                for i in I:
                    for iii in I:
                        if (i,iii,ii,t,j) in aux_idx_b:
                            expr = expr + b[i,iii,ii,t,j]
                Chemo.addConstr(expr <= 1)
            
    for i in I:
        for iii in I:
            for t in T:
                if (iii,t) in x:
                    for j2 in range(x[iii,t]):
                        if (i,iii,t,j2) in aux_idx_w:
                            print(i,iii,t,j2)
                            expr = LinExpr(0.0)
                            for ii in I:
                                if (ii,t-int(ii/slot)) in x:
                                    for j1 in range(x[ii,t-int(ii/slot)]):
                                        if (i,ii,iii,t-int(ii/slot),j1,j2) in aux_idx_v:
                                            expr = expr + v[i,ii,iii,t-int(ii/slot),j1,j2]
                            Chemo.addConstr(expr <= 1)

    cons6 = Chemo.addConstrs(
        y.sum('*',ii,t,j) + z.sum('*',ii,t,j) + w.sum('*',ii,t,j) + 0.5*b.sum('*','*',ii,t,j) <= 1
                   for ii in I for t in T for j in range(x[ii,t])
        )

    cons7 = Chemo.addConstrs(
        u[i,t] == y.sum(i,'*',t,'*') + v.sum(i,'*','*',t,'*','*') + b.sum(i,'*','*',t,'*') + b.sum('*',i,'*',t,'*')
        for i in I for t in T
        )

    cons8 = Chemo.addConstrs(
        q[i] >= P[i] - u.sum(i,'*') for i in I
        )

    cons9 = Chemo.addConstrs(
        a[i] == u.sum(i,'*') for i in I
        )

    # exercise 3
    #L1 = 50
    #L2 = 4
    #L3 = 1
    #L4 = 3
    #L5 = 2
    
    # exercise 2
    L1 = 50
    L2 = 4
    L3 = 1
    L4 = 2
    L5 = 3
    

    objective = L1*q.sum('*') + L2*u.sum('*','*')
    for t in T:
        for ii in I:
            for i in I:
                if i < ii:
                    for j in range(x[ii,t]):
                        objective += L3*y[i,ii,t,j]
                        
    objective += L4*v.sum('*','*','*','*','*','*')
    objective += L4*(z.sum('*','*','*','*') + w.sum('*','*','*','*')) 
    objective += L5*b.sum('*','*','*','*','*')

    Chemo.setObjective(objective, GRB.MINIMIZE)
    Chemo.optimize()


    
    if Chemo.status == GRB.OPTIMAL:
        
        build_in_val=[]
    
        print('\nCost: %g' % Chemo.objVal)
        print('\nStart:')
        build_in_val.append('\nCost: %g' % Chemo.objVal)
        build_in_val.append('\nStart:')
        
        xu = Chemo.getAttr('x', u)
        qu = Chemo.getAttr('x', q)
        yu = Chemo.getAttr('x', y)
        zu = Chemo.getAttr('x', z)
        wu = Chemo.getAttr('x', w)
        bu = Chemo.getAttr('x', b)
        vu = Chemo.getAttr('x', v)
        au = Chemo.getAttr('x', a)

        txt_out=[]
        
       
        print('print u it')
        txt_out.append('print u it')
        for i in I:
            for t in T:
                if u[i,t].x > 0.0001:
                    print('%s %s %g' % (i, t, xu[i,t]))
                    txt_out.append('%d %d %d' % (i, t, round(xu[i,t])))
                    count_asg+=round(xu[i,t])
                    
                    #this means count_asg = count_asg + xu[i,t]
                    
        print('print q i')
        txt_out.append('print q i')
        for i in I:                
            if q[i].x > 0.0001:
                print('%s %g' % (i, round(qu[i])))
                txt_out.append('%s %g' %(i, round(qu[i])))
                    
        print('print a i')
        txt_out.append('print a i')
        for i in I:
            if a[i].x > 0.0001:
                    print('%s, %g' % (i, round(au[i])))
                    txt_out.append('%s, %g' %(i, round(au[i])))
                    
                    
        print('print y iitj')
        txt_out.append('print y iitj')
        for i in I:
            for ii in I:
                for t in T:
                    for j in range(x[ii,t]):
                        if ((i,ii,t,j) in aux_idx_y) and (y[i,ii,t,j].x > 0.01):
                            print('%s %s %s %s, %g' % (i, ii, t, j, yu[i,ii,t,j]))
                            txt_out.append('%s %s %s %s, %g' % (i, ii, t, j, round(yu[i,ii,t,j])))
                            
                            if i<ii:
                                count_y+=1
                                #this means count_y = count_y + 1
                            
        print('print z iitj')
        txt_out.append('print z iitj')
        for i in I:
            for ii in I:
                for t in T:
                    for j in range(x[ii,t]):
                        if ((i,ii,t,j) in aux_idx_z) and (z[i,ii,t,j].x > 0.01):
                            print('%s %s %s %s, %g' % (i, ii, t, j, zu[i,ii,t,j]))
                            txt_out.append('%s %s %s %s, %g' % (i, ii, t, j, round(zu[i,ii,t,j])))
                            count_z+=1

        print('print w iitj')
        txt_out.append('print w iitj')
        for i in I:
            for ii in I:
                for t in T:
                    for j in range(x[ii,t]):
                        if ((i,ii,t,j) in aux_idx_w) and (w[i,ii,t,j].x > 0.01):
                            print('%s %s %s %s, %g' % (i, ii, t, j, wu[i,ii,t,j]))
                            txt_out.append('%s %s %s %s, %g' % (i, ii, t, j, round(wu[i,ii,t,j])))
                            count_w+=1
       
        count_result=min(count_w,count_z)

        print('print v iiit')
        txt_out.append('print v iiit')
        for i in I:
            for ii in I:
                for iii in I:
                    for t in T:
                      if t + ((ii+iii)/slot) in T:
                        for j1 in range(x[ii,t]):
                            for j2 in range(x[iii,t+ii//slot]):
                                if (i,ii,iii,t,j1,j2) in aux_idx_v and (v[i,ii,iii,t,j1,j2].x > 0.01):
                                    print('%s %s %s %s %s, %s, %g' % (i, ii, iii, t, j1, j2, vu[i,ii,iii,t,j1,j2]))
                                    txt_out.append('%s %s %s %s %s, %s, %g' % (i, ii, iii, t, j1, j2, round(vu[i,ii,iii,t,j1,j2])))

        print('print beta iiitj')
        txt_out.append('print beta iiitj')
        
        #print(b)
        for i in I:
            for ii in I:
                for iii in I:
                    for t in T:
                        for j in range(x[iii,t]):
                            if ((i,ii,iii,t,j) in aux_idx_b) and (b[i,ii,iii,t,j].x > 0.01):
                                print('%s %s %s %s %s, %g' % (i, ii, iii, t, j, bu[i,ii,iii,t,j]))
                                txt_out.append('%s %s %s %s %s, %g' % (i, ii, iii, t, j, round(bu[i,ii,iii,t,j])))
                                count_beta+=1
    else:
        txt_out.append('No solution')
        print('No solution')
    counters_=[]
    counters_.append('No. of times a larger block was assigned to a patients requiring smaller time blocks %s'%count_y)
    counters_.append('No. of times two blocks were combined %s'%count_result)
    counters_.append('No. of times a larger block was broken %s'%count_beta)
    counters_.append('No. secondary assignments %d'%int(round((count_asg))))
    
    text_output=counters_+[' ']+build_in_val+txt_out
    
    out_to_excel=(txt_out[txt_out.index('print u it'):txt_out.index('print q i')][1:])
    
    print('text'+str(count+1))
    
    with open(str(count+1)+'.txt', 'w') as filehandle:
        for listitem in text_output:
            filehandle.write('%s\n' % listitem)
            
    values=[]
    for ele in out_to_excel:
        s=ele.split(' ')
        temporary=[]
        for k in s:
            temporary.append(int(k))
        values.append(temporary)
    #print (values)
    values=np.array(values)
    #print(values)
    q=values
   

    a_360=np.zeros((41,1))            #subject to change if we have more than 40 slots
    a_300=np.zeros((41,1))
    a_240=np.zeros((41,1))
    a_180=np.zeros((41,1))
    a_120=np.zeros((41,1))
    a_60=np.zeros((41,1))
    a_30=np.zeros((41,1))
    
    for j in range(q.shape[0]):
        if (q[j][0]==360):
            a_360[q[j][1]]=q[j][2]
        elif (q[j][0]==300):
            a_300[q[j][1]]=q[j][2]
        elif (q[j][0]==240):
            a_240[q[j][1]]=q[j][2]
        elif (q[j][0]==180):
            a_180[q[j][1]]=q[j][2]
        elif (q[j][0]==120):
            a_120[q[j][1]]=q[j][2]
        elif (q[j][0]==60):
            a_60[q[j][1]]=q[j][2]
        elif (q[j][0]==30):
            a_30[q[j][1]]=int(q[j][2])

    values_a_30=[]        
    for a_30_ in a_30:
        values_a_30.append(a_30_[0])
    #print(values_a_30)

    values_a_60=[]        
    for a_60_ in a_60:
        values_a_60.append(a_60_[0])
    #print(values_a_60)

    values_a_120=[]        
    for a_120_ in a_120:
        values_a_120.append(a_120_[0])
    #print(values_a_120)

    values_a_180=[]        
    for a_180_ in a_180:
        values_a_180.append(a_180_[0])
    #print(values_a_180)

    values_a_240=[]        
    for a_240_ in a_240:
        values_a_240.append(a_240_[0])
    #print(values_a_240)

    values_a_300=[]        
    for a_300_ in a_300:
        values_a_300.append(a_300_[0])
    #print(values_a_300)

    values_a_360=[]        
    for a_360_ in a_360:
        values_a_360.append(a_360_[0])
    #print(values_a_360)

    out_dict={30:values_a_30,60:values_a_60,120:values_a_120,180:values_a_180,240:values_a_240,300:values_a_300,360:values_a_360}
    
  
    
    final.append(out_dict)
# Out:
# Streaming output truncated to the last 5000 lines.
# 240 120 3 1
# 240 120 3 2
# 240 120 15 0
# 240 120 21 0
# 240 120 21 1
# 240 120 31 0
# 240 120 31 1
# 240 120 31 2
# 240 60 4 0
# 240 60 7 0
# 240 60 7 1
# 240 60 13 0
# 240 60 13 1
# 240 60 15 0
# 240 60 17 0
# 240 60 29 0
# 240 60 31 0
# 240 60 31 1
# 240 60 31 2
# 240 30 4 0
# 240 30 4 1
# 240 30 8 0
# 240 30 11 0
# 240 30 11 1
# 240 30 11 2
# 240 30 11 3
# 240 30 11 4
# 240 30 13 0
# 240 30 13 1
# 240 30 13 2
# 240 30 15 0
# 240 30 17 0
# 240 30 17 1
# 240 30 17 2
# 240 30 17 3
# 240 30 17 4
# 240 30 22 0
# 240 30 23 0
# 240 30 26 0
# 240 30 33 0
# 240 30 35 0
# 240 30 35 1
# 240 30 36 0
# 240 30 36 1
# 180 120 1 0
# 180 120 3 0
# 180 120 3 1
# 180 120 3 2
# 180 120 15 0
# 180 120 21 0
# 180 120 21 1
# 180 120 31 0
# 180 120 31 1
# 180 120 31 2
# 180 60 4 0
# 180 60 7 0
# 180 60 7 1
# 180 60 13 0
# 180 60 13 1
# 180 60 15 0
# 180 60 17 0
# 180 60 29 0
# 180 60 31 0
# 180 60 31 1
# 180 60 31 2
# 180 30 4 0
# 180 30 4 1
# 180 30 8 0
# 180 30 11 0
# 180 30 11 1
# 180 30 11 2
# 180 30 11 3
# 180 30 11 4
# 180 30 13 0
# 180 30 13 1
# 180 30 13 2
# 180 30 15 0
# 180 30 17 0
# 180 30 17 1
# 180 30 17 2
# 180 30 17 3
# 180 30 17 4
# 180 30 22 0
# 180 30 23 0
# 180 30 26 0
# 180 30 33 0
# 180 30 35 0
# 180 30 35 1
# 180 30 36 0
# 180 30 36 1
# 120 60 4 0
# 120 60 7 0
# 120 60 7 1
# 120 60 13 0
# 120 60 13 1
# 120 60 15 0
# 120 60 17 0
# 120 60 29 0
# 120 60 31 0
# 120 60 31 1
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0x14a562c0
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 3050.0000000
# Presolve removed 1175 rows and 1012 columns
# Presolve time: 0.03s
# Presolved: 143 rows, 472 columns, 1284 nonzeros
# Variable types: 0 continuous, 472 integer (466 binary)
# Found heuristic solution: objective 2842.0000000
#
# Root relaxation: objective 2.460000e+02, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     246.0000000  246.00000  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 246 2842 3050
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.460000000000e+02, best bound 2.460000000000e+02, gap 0.0000%
#
# Cost: 246
#
# Start:
# print u it
# 240 1 3
# 240 25 3
# 180 9 1
# 180 10 1
# 180 19 5
# 180 26 1
# 180 28 1
# 120 1 1
# 120 3 3
# 120 15 1
# 120 19 1
# 120 21 2
# 120 29 1
# 120 31 3
# 60 4 1
# 60 7 2
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 1
# 60 31 3
# 30 4 2
# 30 8 1
# 30 11 5
# 30 13 3
# 30 15 1
# 30 17 5
# 30 22 1
# 30 23 1
# 30 26 1
# 30 33 1
# 30 35 2
# print q i
# print a i
# 240, 6
# 180, 9
# 120, 12
# 60, 11
# 30, 23
# print y iitj
# 240 240 1 0, 1
# 240 240 1 1, 1
# 240 240 1 2, 1
# 240 240 25 0, 1
# 240 240 25 1, 1
# 240 240 25 2, 1
# 180 180 9 0, 1
# 180 180 10 0, 1
# 180 180 19 0, 1
# 180 180 19 1, 1
# 180 180 19 2, 1
# 180 180 19 3, 1
# 180 180 19 4, 1
# 180 180 26 0, 1
# 180 180 28 0, 1
# 120 180 19 5, 1
# 120 180 29 0, 1
# 120 120 1 0, 1
# 120 120 3 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 15 0, 1
# 120 120 21 0, 1
# 120 120 21 1, 1
# 120 120 31 0, 1
# 120 120 31 1, 1
# 120 120 31 2, 1
# 60 60 4 0, 1
# 60 60 7 0, 1
# 60 60 7 1, 1
# 60 60 13 0, 1
# 60 60 13 1, 1
# 60 60 15 0, 1
# 60 60 17 0, 1
# 60 60 29 0, 1
# 60 60 31 0, 1
# 60 60 31 1, 1
# 60 60 31 2, 1
# 30 30 4 0, 1
# 30 30 4 1, 1
# 30 30 8 0, 1
# 30 30 11 0, 1
# 30 30 11 1, 1
# 30 30 11 2, 1
# 30 30 11 3, 1
# 30 30 11 4, 1
# 30 30 13 0, 1
# 30 30 13 1, 1
# 30 30 13 2, 1
# 30 30 15 0, 1
# 30 30 17 0, 1
# 30 30 17 1, 1
# 30 30 17 2, 1
# 30 30 17 3, 1
# 30 30 17 4, 1
# 30 30 22 0, 1
# 30 30 23 0, 1
# 30 30 26 0, 1
# 30 30 33 0, 1
# 30 30 35 0, 1
# 30 30 35 1, 1
# print z iitj
# 240 60 7 0
# 240 60 7 1
# 240 60 13 0
# 240 60 13 1
# 240 60 15 0
# 240 60 17 0
# 240 60 29 0
# 240 60 31 0
# 240 60 31 1
# 240 60 31 2
# 240 30 4 0
# 240 30 4 1
# 240 30 8 0
# 240 30 11 0
# 240 30 11 1
# 240 30 11 2
# 240 30 11 3
# 240 30 11 4
# 240 30 13 0
# 240 30 13 1
# 240 30 13 2
# 240 30 15 0
# 240 30 17 0
# 240 30 17 1
# 240 30 17 2
# 240 30 17 3
# 240 30 17 4
# 240 30 22 0
# 240 30 23 0
# 240 30 26 0
# 240 30 33 0
# 240 30 35 0
# 240 30 35 1
# 240 30 36 0
# 240 30 36 1
# 180 120 1 0
# 180 120 3 0
# 180 120 3 1
# 180 120 3 2
# 180 120 15 0
# 180 120 21 0
# 180 120 21 1
# 180 120 31 0
# 180 120 31 1
# 180 120 31 2
# 180 60 4 0
# 180 60 7 0
# 180 60 7 1
# 180 60 13 0
# 180 60 13 1
# 180 60 15 0
# 180 60 17 0
# 180 60 29 0
# 180 60 31 0
# 180 60 31 1
# 180 60 31 2
# 180 30 4 0
# 180 30 4 1
# 180 30 8 0
# 180 30 11 0
# 180 30 11 1
# 180 30 11 2
# 180 30 11 3
# 180 30 11 4
# 180 30 13 0
# 180 30 13 1
# 180 30 13 2
# 180 30 15 0
# 180 30 17 0
# 180 30 17 1
# 180 30 17 2
# 180 30 17 3
# 180 30 17 4
# 180 30 22 0
# 180 30 23 0
# 180 30 26 0
# 180 30 33 0
# 180 30 35 0
# 180 30 35 1
# 180 30 36 0
# 180 30 36 1
# 120 60 4 0
# 120 60 7 0
# 120 60 7 1
# 120 60 13 0
# 120 60 13 1
# 120 60 15 0
# 120 60 17 0
# 120 60 29 0
# 120 60 31 0
# 120 60 31 1
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0xa94fd30d
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2700.0000000
# Presolve removed 1175 rows and 1010 columns
# Presolve time: 0.02s
# Presolved: 143 rows, 474 columns, 1286 nonzeros
# Found heuristic solution: objective 2393.0000000
# Variable types: 0 continuous, 474 integer (468 binary)
# Found heuristic solution: objective 2077.0000000
#
# Root relaxation: objective 3.090000e+02, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     309.0000000  309.00000  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.09 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 309 2077 2393 2700
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.090000000000e+02, best bound 3.090000000000e+02, gap 0.0000%
#
# Cost: 309
#
# Start:
# print u it
# 360 2 2
# 240 1 1
# 240 25 1
# 180 10 1
# 180 19 4
# 180 26 1
# 120 1 1
# 120 3 3
# 120 15 1
# 120 21 2
# 120 25 1
# 120 31 3
# 60 4 1
# 60 7 2
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 1
# 60 31 2
# 30 8 1
# 30 11 5
# 30 13 3
# 30 15 1
# 30 17 5
# 30 22 1
# 30 23 1
# 30 26 1
# 30 33 1
# 30 35 2
# print q i
# 360 2
# print a i
# 360, 2
# 240, 2
# 180, 6
# 120, 11
# 60, 10
# 30, 21
# print y iitj
# 360 360 2 0, 1
# 360 360 2 1, 1
# 240 240 1 0, 1
# 240 240 25 1, 1
# 180 180 10 0, 1
# 180 180 19 0, 1
# 180 180 19 1, 1
# 180 180 19 3, 1
# 180 180 19 4, 1
# 180 180 26 0, 1
# 120 240 25 2, 1
# 120 120 1 0, 1
# 120 120 3 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 15 0, 1
# 120 120 21 0, 1
# 120 120 21 1, 1
# 120 120 31 0, 1
# 120 120 31 1, 1
# 120 120 31 2, 1
# 60 60 4 0, 1
# 60 60 7 0, 1
# 60 60 7 1, 1
# 60 60 13 0, 1
# 60 60 13 1, 1
# 60 60 15 0, 1
# 60 60 17 0, 1
# 60 60 29 0, 1
# 60 60 31 0, 1
# 60 60 31 1, 1
# 30 30 8 0, 1
# 30 30 11 0, 1
# 30 30 11 1, 1
# 30 30 11 2, 1
# 30 30 11 3, 1
# 30 30 11 4, 1
# 30 30 13 0, 1
# 30 30 13 1, 1
# 30 30 13 2, 1
# 30 30 15 0, 1
# 30 30 17 0, 1
# 30 30 17 1, 1
# 30 30 17 2, 1
# 30 30 17 3, 1
# 30 30 17 4, 1
# 30 30 22 0, 1
# 30 30 23 0, 1
# 30 30 26 0, 1
# 30 30 33 0, 1
# 30 30 35 0, 1
# 30 30 35 1, 1
# print z iitj
# print w iitj
# print v iiit
# print beta iiitj
# text12
# 360 300 5 0
# 360 300 5 1
# 360 240 1 0
# 360 240 1 1
# 360 240 1 2
# 360 240 24 0
# 360 240 25 0
# 360 240 25 1
# 360 240 25 2
# 360 180 9 0
# 360 180 10 0
# 360 180 19 0
# 360 180 19 1
# 360 180 19 2
# 360 180 19 3
# 360 180 19 4
# 360 180 19 5
# 360 180 26 0
# 360 180 28 0
# 360 180 29 0
# 360 120 1 0
# 360 120 3 0
# 360 120 3 1
# 360 120 3 2
# 360 120 15 0
# 360 120 21 0
# 360 120 21 1
# 360 120 31 0
# 360 120 31 1
# 360 120 31 2
# 360 60 4 0
# 360 60 7 0
# 360 60 7 1
# 180 120 3 0
# 180 120 3 1
# 180 120 3 2
# 180 120 15 0
# 180 120 21 0
# 180 120 21 1
# 180 120 31 0
# 180 120 31 1
# 180 120 31 2
# 180 60 4 0
# 180 60 7 0
# 180 60 7 1
# 180 60 13 0
# 180 60 13 1
# 180 60 15 0
# 180 60 17 0
# 180 60 29 0
# 180 60 31 0
# 180 60 31 1
# 180 60 31 2
# 180 30 4 0
# 180 30 4 1
# 180 30 8 0
# 180 30 11 0
# 180 30 11 1
# 180 30 11 2
# 180 30 11 3
# 180 30 11 4
# 180 30 13 0
# 180 30 13 1
# 180 30 13 2
# 180 30 15 0
# 180 30 17 0
# 180 30 17 1
# 180 30 17 2
# 180 30 17 3
# 180 30 17 4
# 180 30 22 0
# 180 30 23 0
# 180 30 26 0
# 180 30 33 0
# 180 30 35 0
# 180 30 35 1
# 180 30 36 0
# 180 30 36 1
# 120 60 4 0
# 120 60 7 0
# 120 60 7 1
# 120 60 13 0
# 120 60 13 1
# 120 60 15 0
# 120 60 17 0
# 120 60 29 0
# 120 60 31 0
# 120 60 31 1
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0xb626221c
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 3450.0000000
# Presolve removed 1175 rows and 1010 columns
# Presolve time: 0.03s
# Presolved: 143 rows, 474 columns, 1286 nonzeros
# Found heuristic solution: objective 3143.0000000
# Variable types: 0 continuous, 474 integer (468 binary)
# Found heuristic solution: objective 2827.0000000
#
# Root relaxation: objective 3.270000e+02, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     327.0000000  327.00000  0.00%     -    0s
#
# Explored 1 nodes (42 simplex iterations) in 0.09 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 327 2827 3143 3450
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3
# 180 120 31 2
# 180 60 4 0
# 180 60 7 0
# 180 60 7 1
# 180 60 13 0
# 180 60 13 1
# 180 60 15 0
# 180 60 17 0
# 180 60 29 0
# 180 60 31 0
# 180 60 31 1
# 180 60 31 2
# 180 30 4 0
# 180 30 4 1
# 180 30 8 0
# 180 30 11 0
# 180 30 11 1
# 180 30 11 2
# 180 30 11 3
# 180 30 11 4
# 180 30 13 0
# 180 30 13 1
# 180 30 13 2
# 180 30 15 0
# 180 30 17 0
# 180 30 17 1
# 180 30 17 2
# 180 30 17 3
# 180 30 17 4
# 180 30 22 0
# 180 30 23 0
# 180 30 26 0
# 180 30 33 0
# 180 30 35 0
# 180 30 35 1
# 180 30 36 0
# 180 30 36 1
# 120 60 4 0
# 120 60 7 0
# 120 60 7 1
# 120 60 13 0
# 120 60 13 1
# 120 60 15 0
# 120 60 17 0
# 120 60 29 0
# 120 60 31 0
# 120 60 31 1
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0x596dac55
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2500.0000000
# Presolve removed 1175 rows and 1012 columns
# Presolve time: 0.02s
# Presolved: 143 rows, 472 columns, 1284 nonzeros
# Variable types: 0 continuous, 472 integer (466 binary)
# Found heuristic solution: objective 2292.0000000
#
# Root relaxation: objective 2.010000e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     201.0000000  201.00000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 201 2292 2500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.010000000000e+02, best bound 2.010000000000e+02, gap 0.0000%
#
# Cost: 201
#
# Start:
# print u it
# 240 1 1
# 240 25 1
# 180 9 1
# 180 10 1
# 180 19 6
# 180 24 1
# 180 26 1
# 180 28 1
# 180 29 1
# 120 1 1
# 120 3 3
# 120 15 1
# 120 21 2
# 120 31 3
# 60 4 1
# 60 7 2
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 1
# 60 31 3
# 30 8 1
# 30 11 3
# 30 13 3
# 30 15 1
# 30 17 4
# 30 33 1
# 30 35 2
# print q i
# print a i
# 240, 2
# 180, 12
# 120, 10
# 60, 11
# 30, 15
# print y iitj
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0x315c8c73
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 2800.0000000
# Presolve removed 1175 rows and 1010 columns
# Presolve time: 0.02s
# Presolved: 143 rows, 474 columns, 1286 nonzeros
# Found heuristic solution: objective 2493.0000000
# Variable types: 0 continuous, 474 integer (468 binary)
# Found heuristic solution: objective 2177.0000000
#
# Root relaxation: objective 2.760000e+02, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     276.0000000  276.00000  0.00%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 276 2177 2493 2800
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.760000000000e+02, best bound 2.760000000000e+02, gap 0.0000%
#
# Cost: 276
#
# Start:
# print u it
# 360 2 2
# 240 1 1
# 240 25 1
# 180 10 1
# 180 19 3
# 180 26 1
# 120 3 2
# 120 15 1
# 120 21 1
# 120 31 3
# 60 4 1
# 60 7 1
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 1
# 60 31 1
# 30 1 1
# 30 3 1
# 30 4 2
# 30 7 1
# 30 8 1
# 30 11 5
# 30 13 3
# 30 15 1
# 30 17 5
# 30 22 1
# 30 23 1
# 30 25 1
# 30 26 1
# 30 31 2
# 30 33 1
# 30 35 2
# 30 36 2
# print q i
# 360 1
# print a i
# 360, 2
# 240, 2
# 180, 5
# 120, 7
# 60, 8
# 30, 31
# print y iitj
# 360 360 2 0, 1
# 360 360 2 1, 1
# 240 240 1 0, 1
# 240 240 25 0, 1
# 180 180 10 0, 1
# 180 180 19 0, 1
# 180 180 19 1, 1
# 180 180 19 4, 1
# 180 180 26 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 15 0, 1
# 120 120 21 0, 1
# 120 120 31 0, 1
# 120 120 31 1, 1
# 120 120 31 2, 1
# 60 60 4 0, 1
# 60 60 7 0, 1
# 60 60 13 0, 1
# 60 60 13 1, 1
# 60 60 15 0, 1
# 60 60 17 0, 1
# 60 60 29 0, 1
# 60 60 31 0, 1
# 30 240 25 1, 1
# 30 120 1 0, 1
# 30 120 3 0, 1
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0xe90a21c5
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1950.0000000
# Presolve removed 1174 rows and 1009 columns
# Presolve time: 0.03s
# Presolved: 144 rows, 475 columns, 1289 nonzeros
# Variable types: 0 continuous, 475 integer (469 binary)
# Found heuristic solution: objective 1695.0000000
#
# Root relaxation: objective 1.570000e+02, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     157.0000000  157.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.09 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 157 1695 1950
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.570000000000e+02, best bound 1.570000000000e+02, gap 0.0000%
#
# Cost: 157
#
# Start:
# print u it
# 360 2 1
# 240 1 1
# 240 25 1
# 180 10 1
# 180 19 2
# 180 26 1
# 120 1 1
# 120 3 2
# 120 15 1
# 120 31 2
# 60 4 1
# 60 7 2
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 2
# 60 31 3
# 30 11 3
# 30 13 3
# 30 15 1
# 30 17 3
# 30 33 1
# 30 35 2
# 30 36 1
# print q i
# print a i
# 360, 1
# 240, 2
# 180, 4
# 120, 6
# 60, 12
# 30, 14
# print y iitj
# 360 360 2 0, 1
# 240 240 1 0, 1
# 240 240 25 1, 1
# 180 180 10 0, 1
# 180 180 19 1, 1
# 180 180 19 4, 1
# 180 180 26 0, 1
# 120 120 1 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 15 0, 1
# 120 120 31 0, 1
# 120 120 31 1, 1
# 60 180 29 0, 1
# 60 60 4 0, 1
# 60 60 7 0, 1
# 60 60 7 1, 1
# 60 60 13 0, 1
# 60 60 13 1, 1
# 60 60 15 0, 1
# 60 60 17 0, 1
# 60 60 29 0, 1
# 60 60 31 0, 1
# 60 60 31 1, 1
# 60 60 31 2, 1
# 30 30 11 0, 1
# 30 30 11 3, 1
# 30 30 11 4, 1
# 30 30 13 0, 1
# 30 30 13 1, 1
# 30 30 13 2, 1
# 30 30 15 0, 1
# 30 30 17 0, 1
# 30 30 17 3, 1
# 30 30 17 4, 1
# 30 30 33 0, 1
# 30 30 35 0, 1
# 30 30 35 1, 1
# 30 30 36 1, 1
# print z iitj
# print w iitj
# print v iiit
# print beta iiitj
# text16
# 360 300 5 0
# 360 300 5 1
# 360 240 1 0
# 360 240 1 1
# 360 240 1 2
# 360 240 24 0
# 360 240 25 0
# 360 240 25 1
# 360 240 25 2
# 360 180 9 0
# 360 180 10 0
# 360 180 19 0
# 360 180 19 1
# 360 180 19 2
# 360 180 19 3
# 360 180 19 4
# 360 180 19 5
# 360 180 26 0
# 360 180 28 0
# 240 30 17 1
# 240 30 17 2
# 240 30 17 3
# 240 30 17 4
# 240 30 22 0
# 240 30 23 0
# 240 30 26 0
# 240 30 33 0
# 240 30 35 0
# 240 30 35 1
# 240 30 36 0
# 240 30 36 1
# 180 120 1 0
# 180 120 3 0
# 180 120 3 1
# 180 120 3 2
# 180 120 15 0
# 180 120 21 0
# 180 120 21 1
# 180 120 31 0
# 180 120 31 1
# 180 120 31 2
# 180 60 4 0
# 180 60 7 0
# 180 60 7 1
# 180 60 13 0
# 180 60 13 1
# 180 60 15 0
# 180 60 17 0
# 180 60 29 0
# 180 60 31 0
# 180 60 31 1
# 180 60 31 2
# 180 30 4 0
# 180 30 4 1
# 180 30 8 0
# 180 30 11 0
# 180 30 11 1
# 180 30 11 2
# 180 30 11 3
# 180 30 11 4
# 180 30 13 0
# 180 30 13 1
# 180 30 13 2
# 180 30 15 0
# 180 30 17 0
# 180 30 17 1
# 180 30 17 2
# 180 30 17 3
# 180 30 17 4
# 180 30 22 0
# 180 30 23 0
# 180 30 26 0
# 180 30 33 0
# 180 30 35 0
# 180 30 35 1
# 180 30 36 0
# 180 30 36 1
# 120 60 4 0
# 120 60 7 0
# 120 60 7 1
# 120 60 13 0
# 120 60 13 1
# 120 60 15 0
# 120 60 17 0
# 120 60 29 0
# 120 60 31 0
# 120 60 31 1
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0x30e9d2da
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2550.0000000
# Presolve removed 1175 rows and 1010 columns
# Presolve time: 0.03s
# Presolved: 143 rows, 474 columns, 1286 nonzeros
# Found heuristic solution: objective 2243.0000000
# Variable types: 0 continuous, 474 integer (468 binary)
# Found heuristic solution: objective 1927.0000000
#
# Root relaxation: objective 2.040000e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     204.0000000  204.00000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.09 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 204 1927 2243 2550
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2
# 180 30 13 0
# 180 30 13 1
# 180 30 13 2
# 180 30 15 0
# 180 30 17 0
# 180 30 17 1
# 180 30 17 2
# 180 30 17 3
# 180 30 17 4
# 180 30 22 0
# 180 30 23 0
# 180 30 26 0
# 180 30 33 0
# 180 30 35 0
# 180 30 35 1
# 180 30 36 0
# 180 30 36 1
# 120 60 4 0
# 120 60 7 0
# 120 60 7 1
# 120 60 13 0
# 120 60 13 1
# 120 60 15 0
# 120 60 17 0
# 120 60 29 0
# 120 60 31 0
# 120 60 31 1
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0x3c330c59
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2150.0000000
# Presolve removed 1175 rows and 1010 columns
# Presolve time: 0.02s
# Presolved: 143 rows, 474 columns, 1286 nonzeros
# Found heuristic solution: objective 1843.0000000
# Variable types: 0 continuous, 474 integer (468 binary)
# Found heuristic solution: objective 1527.0000000
#
# Root relaxation: objective 1.720000e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     172.0000000  172.00000  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 172 1527 1843 2150
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.720000000000e+02, best bound 1.720000000000e+02, gap 0.0000%
#
# Cost: 172
#
# Start:
# print u it
# 360 2 2
# 240 1 3
# 240 25 2
# 180 10 1
# 180 19 3
# 180 26 1
# 120 1 1
# 120 3 2
# 120 31 2
# 60 4 1
# 60 7 2
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 1
# 60 31 2
# 30 8 1
# 30 11 4
# 30 13 3
# 30 15 1
# 30 17 4
# 30 33 1
# 30 35 2
# print q i
# print a i
# 360, 2
# 240, 5
# 180, 5
# 120, 5
# 60, 10
# 30, 16
# print y iitj
# 360 360 2 0, 1
# 360 360 2 1, 1
# 240 240 1 0, 1
# 240 240 1 1, 1
# 240 240 1 2, 1
# 240 240 25 1, 1
# 240 240 25 2, 1
# 180 180 10 0, 1
# 180 180 19 0, 1
# 180 180 19 1, 1
# 180 180 19 4, 1
# 180 180 26 0, 1
# 120 120 1 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 31 0, 1
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0xee1ab3f1
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2550.0000000
# Presolve removed 1174 rows and 1009 columns
# Presolve time: 0.03s
# Presolved: 144 rows, 475 columns, 1289 nonzeros
# Variable types: 0 continuous, 475 integer (469 binary)
# Found heuristic solution: objective 2295.0000000
#
# Root relaxation: objective 2.040000e+02, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     204.0000000  204.00000  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 204 2295 2550
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.040000000000e+02, best bound 2.040000000000e+02, gap 0.0000%
#
# Cost: 204
#
# Start:
# print u it
# 360 2 1
# 240 1 2
# 240 25 2
# 180 10 1
# 180 19 6
# 180 26 1
# 120 1 1
# 120 3 2
# 120 31 1
# 60 4 1
# 60 7 2
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 1
# 60 31 2
# 30 4 2
# 30 8 1
# 30 11 5
# 30 13 3
# 30 15 1
# 30 17 5
# 30 22 1
# 30 23 1
# 30 33 1
# 30 35 2
# 30 36 2
# print q i
# print a i
# 360, 1
# 240, 4
# 180, 8
# 120, 4
# 60, 10
# 30, 24
# print y iitj
# 360 360 2 0, 1
# 240 240 1 0, 1
# 240 240 1 1, 1
# 240 240 25 1, 1
# 240 240 25 2, 1
# 180 180 10 0, 1
# 180 180 19 0, 1
# 180 180 19 1, 1
# 180 180 19 2, 1
# 180 180 19 3, 1
# 180 180 19 4, 1
# 180 180 19 5, 1
# 180 180 26 0, 1
# 120 120 1 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 31 0, 1
# 60 60 4 0, 1
# 60 60 7 0, 1
# 60 60 7 1, 1
# 60 60 13 0, 1
# 60 60 13 1, 1
# 60 60 15 0, 1
# 60 60 17 0, 1
# 60 60 29 0, 1
# 60 60 31 0, 1
# 60 60 31 1, 1
# 30 30 4 0, 1
# 30 30 4 1, 1
# 30 30 8 0, 1
# 30 30 11 0, 1
# 30 30 11 1, 1
# 30 30 11 2, 1
# 30 30 11 3, 1
# 30 30 11 4, 1
# 30 30 13 0, 1
# 30 30 13 1, 1
1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0x8c52a666
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2050.0000000
# Presolve removed 1174 rows and 1009 columns
# Presolve time: 0.03s
# Presolved: 144 rows, 475 columns, 1289 nonzeros
# Variable types: 0 continuous, 475 integer (469 binary)
# Found heuristic solution: objective 1795.0000000
#
# Root relaxation: objective 1.640000e+02, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     164.0000000  164.00000  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.09 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 164 1795 2050
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.640000000000e+02, best bound 1.640000000000e+02, gap 0.0000%
#
# Cost: 164
#
# Start:
# print u it
# 360 2 1
# 240 1 3
# 240 25 2
# 180 10 1
# 180 19 3
# 180 26 1
# 120 1 1
# 120 3 2
# 120 15 1
# 120 21 1
# 120 31 3
# 60 4 1
# 60 7 1
# 60 13 2
# 60 15 1
# 30 11 4
# 30 13 3
# 30 15 1
# 30 17 5
# 30 33 1
# 30 35 2
# 30 36 1
# print q i
# print a i
# 360, 1
# 240, 5
# 180, 5
# 120, 8
# 60, 5
# 30, 17
# print y iitj
# 360 360 2 0, 1
# 240 240 1 0, 1
# 240 240 1 1, 1
# 240 240 1 2, 1
# 240 240 25 1, 1
# 240 240 25 2, 1
# 180 180 10 0, 1
# 180 180 19 0, 1
# 180 180 19 1, 1
# 180 180 19 4, 1
# 180 180 26 0, 1
# 120 120 1 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 15 0, 1
# 120 120 21 0, 1
# 120 120 31 0, 1
# 120 120 31 1, 1
# 120 120 31 2, 1
# 60 60 4 0, 1
# 60 60 7 0, 1
# 60 60 13 0, 1
# 60 60 13 1, 1
# 60 60 15 0, 1
# 30 30 11 0, 1
# 30 30 11 1, 1
# 30 30 11 3, 1
# 30 30 11 4, 1
# 30 30 13 0, 1
# 30 30 13 1, 1
# 30 30 13 2, 1
# 30 30 15 0, 1
# 30 30 17 0, 1
# 30 30 17 1, 1
# 30 30 17 2, 1
# 30 30 17 3, 1
# 30 30 17 4, 1
# 30 30 33 0, 1
# 30 30 35 0, 1
# 30 30 35 1, 1
# 30 30 36 1, 1
# print z iitj
# print w iitj
# print v iiit
# print beta iiitj
# text21
# 360 300 5 0
# 360 300 5 1
# 360 240 1 0
# 360 240 1 1
# 360 240 1 2
# 360 240 24 0
# 360 240 25 0
# 360 240 25 1
# 360 240 25 2
# 360 180 9 0
# 360 180 10 0
# 360 180 19 0
# 360 180 19 1
# 360 180 19 2
# 360 180 19 3
# 360 180 19 4
# 360 180 19 5
# 360 180 26 0
# 360 180 28 0
# 360 180 29 0
# 360 120 1 0
# 360 120 3 0
# 360 120 3 1
# 360 120 3 2
# 360 120 15 0
# 360 120 21 0
# 360 120 21 1
# 360 120 31 0
# 360 120 31 1
# 360 120 31 2
# 360 60 4 0
# 360 60 7 0
# 360 60 7 1
# 360 60 13 0
# 360 60 13 1
# 360 60 15 0
# 360 60 17 0
# 180 120 21 1
# 180 120 31 0
# 180 120 31 1
# 180 120 31 2
# 180 60 4 0
# 180 60 7 0
# 180 60 7 1
# 180 60 13 0
# 180 60 13 1
# 180 60 15 0
# 180 60 17 0
# 180 60 29 0
# 180 60 31 0
# 180 60 31 1
# 180 60 31 2
# 180 30 4 0
# 180 30 4 1
# 180 30 8 0
# 180 30 11 0
# 180 30 11 1
# 180 30 11 2
# 180 30 11 3
# 180 30 11 4
# 180 30 13 0
# 180 30 13 1
# 180 30 13 2
# 180 30 15 0
# 180 30 17 0
# 180 30 17 1
# 180 30 17 2
# 180 30 17 3
# 180 30 17 4
# 180 30 22 0
# 180 30 23 0
# 180 30 26 0
# 180 30 33 0
# 180 30 35 0
# 180 30 35 1
# 180 30 36 0
# 180 30 36 1
# 120 60 4 0
# 120 60 7 0
# 120 60 7 1
# 120 60 13 0
# 120 60 13 1
# 120 60 15 0
# 120 60 17 0
# 120 60 29 0
# 120 60 31 0
# 120 60 31 1
# 120 60 31 2
# 120 30 4 0
# 120 30 4 1
# 120 30 8 0
# 120 30 11 0
# 120 30 11 1
# 120 30 11 2
# 120 30 11 3
# 120 30 11 4
# 120 30 13 0
# 120 30 13 1
# 120 30 13 2
# 120 30 15 0
# 120 30 17 0
# 120 30 17 1
# 120 30 17 2
# 120 30 17 3
# 120 30 17 4
# 120 30 22 0
# 120 30 23 0
# 120 30 26 0
# 120 30 33 0
# 120 30 35 0
# 120 30 35 1
# 120 30 36 0
# 120 30 36 1
# 60 30 4 0
# 60 30 4 1
# 60 30 8 0
# 60 30 11 0
# 60 30 11 1
# 60 30 11 2
# 60 30 11 3
# 60 30 11 4
# 60 30 13 0
# 60 30 13 1
# 60 30 13 2
# 60 30 15 0
# 60 30 17 0
# 60 30 17 1
# 60 30 17 2
# 60 30 17 3
# 60 30 17 4
# 60 30 22 0
# 60 30 23 0
# 60 30 26 0
# 60 30 33 0
# 60 30 35 0
# 60 30 35 1
# 60 30 36 0
# 60 30 36 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1318 rows, 1484 columns and 3998 nonzeros
# Model fingerprint: 0x3b4e2b3b
# Variable types: 0 continuous, 1484 integer (1090 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+00]
#   Objective range  [1e+00, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 3400.0000000
# Presolve removed 1147 rows and 968 columns
# Presolve time: 0.04s
# Presolved: 171 rows, 516 columns, 1451 nonzeros
# Found heuristic solution: objective 3047.0000000
# Variable types: 0 continuous, 516 integer (509 binary)
# Found heuristic solution: objective 2685.0000000
#
# Root relaxation: objective 2.720000e+02, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     272.0000000  272.00000  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 272 2685 3047 3400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.720000000000e+02, best bound 2.720000000000e+02, gap 0.0000%
#
# Cost: 272
#
# Start:
# print u it
# 360 2 2
# 300 5 2
# 240 1 3
# 240 24 1
# 240 25 3
# 180 9 1
# 180 10 1
# 180 19 6
# 180 26 1
# 180 28 1
# 180 29 1
# 120 1 1
# 120 3 3
# 120 15 1
# 120 21 2
# 120 31 3
# 60 4 1
# 60 7 2
# 60 13 2
# 60 15 1
# 60 17 1
# 60 29 1
# 60 31 3
# 30 4 2
# 30 8 1
# 30 11 5
# 30 13 3
# 30 15 1
# 30 17 5
# 30 22 1
# 30 23 1
# 30 26 1
# 30 33 1
# 30 35 2
# 30 36 2
# print q i
# print a i
# 360, 2
# 300, 2
# 240, 7
# 180, 11
# 120, 10
# 60, 11
# 30, 25
# print y iitj
# 360 360 2 0, 1
# 360 360 2 1, 1
# 300 300 5 0, 1
# 300 300 5 1, 1
# 240 240 1 0, 1
# 240 240 1 1, 1
# 240 240 1 2, 1
# 240 240 24 0, 1
# 240 240 25 0, 1
# 240 240 25 1, 1
# 240 240 25 2, 1
# 180 180 9 0, 1
# 180 180 10 0, 1
# 180 180 19 0, 1
# 180 180 19 1, 1
# 180 180 19 2, 1
# 180 180 19 3, 1
# 180 180 19 4, 1
# 180 180 19 5, 1
# 180 180 26 0, 1
# 180 180 28 0, 1
# 180 180 29 0, 1
# 120 120 1 0, 1
# 120 120 3 0, 1
# 120 120 3 1, 1
# 120 120 3 2, 1
# 120 120 15 0, 1
# 120 120 21 0, 1
# 120 120 21 1, 1
# 120 120 31 0, 1
# 120 120 31 1, 1
# 120 120 31 2, 1
# 60 60 4 0, 1
# 60 60 7 0, 1
# 60 60 7 1, 1
# 60 60 13 0, 1
# 60 60 13 1, 1
# 60 60 15 0, 1
# 60 60 17 0, 1
# 60 60 29 0, 1
# 60 60 31 0, 1
# 60 60 31 1, 1
# 60 60 31 2, 1
# 30 30 4 0, 1
# 30 30 4 1, 1
# 30 30 8 0, 1
# 30 30 11 0, 1
# 30 30 11 1, 1
# 30 30 11 2, 1
# 30 30 11 3, 1
# 30 30 11 4, 1
# 30 30 13 0, 1
# 30 30 13 1, 1
# 30 30 13 2, 1
# 30 30 15 0, 1
# 30 30 17 0, 1
# 30 30 17 1, 1
# 30 30 17 2, 1
# 30 30 17 3, 1
# 30 30 17 4, 1
# 30 30 22 0, 1
# 30 30 23 0, 1
# 30 30 26 0, 1
# 30 30 33 0, 1
# 30 30 35 0, 1
# 30 30 35 1, 1
# 30 30 36 0, 1
# 30 30 36 1, 1
# print z iitj
# print w iitj
# print v iiit
# print beta iiitj
# text22

# %%
#subject to change if we have timeslots after 4:45    
import datetime
order=pd.DataFrame([0,datetime.time(7, 0), datetime.time(7, 15), datetime.time(7, 30),
                   datetime.time(7, 45), datetime.time(8, 0), datetime.time(8, 15),
                   datetime.time(8, 30), datetime.time(8, 45), datetime.time(9, 0),
                   datetime.time(9, 15), datetime.time(9, 30), datetime.time(9, 45),
                   datetime.time(10, 0), datetime.time(10, 15), datetime.time(10, 30),
                   datetime.time(10, 45), datetime.time(11, 0), datetime.time(11, 15),
                   datetime.time(11, 30), datetime.time(11, 45), datetime.time(12, 0),
                   datetime.time(12, 15), datetime.time(12, 30),
                   datetime.time(12, 45), datetime.time(13, 0), datetime.time(13, 15),
                   datetime.time(13, 30), datetime.time(13, 45), datetime.time(14, 0),
                   datetime.time(14, 15), datetime.time(14, 30),
                   datetime.time(14, 45), datetime.time(15, 0), datetime.time(15, 15),
                   datetime.time(15, 30), datetime.time(15, 45), datetime.time(16, 0),
                   datetime.time(16, 15), datetime.time(16, 30),
                   datetime.time(16, 45)],columns=['time'])




writer = pd.ExcelWriter('output.xlsx')
for i in range(len(final)):
    df = pd.DataFrame(final[i]) 
    df=df.iloc[1:,:]
    df=pd.concat([order.iloc[1:,:],df],axis='columns')
    df.to_excel(writer, "Sheet{}".format(i + 1))
writer.save()

# %%
import openpyxl
import os

patients = openpyxl.load_workbook('output.xlsx')
nurses = openpyxl.load_workbook('/content/drive/MyDrive/GOOGLE_COLAB/MAYO/data.xlsx')['StaffLevel']

final = openpyxl.Workbook() 
sheet = final.active

for o in range(1,len(patients.worksheets)+1):
    sheet.cell(row = o+1,column=1).value = o 
    
sheet.cell(row=1, column = 1).value = "sample"
sheet.cell(row=1, column = 2).value = "3:1 violations"
sheet.cell(row=1, column = 3).value = "1:1 violations"
sheet.cell(row=1, column = 4).value = "overrides"

count = 1
for x in patients.worksheets:
    total_pt = 0
    total_vln1 = 0 
    total_vln2 = 0
    for i in range(2,x.max_row+1):
        strt = 0
        end = 0
        cont = 0
        vln_1 = 0
        vln_2 = 0
        for j in range(3,x.max_column+1):
            strt = strt + x.cell(row=i, column=j).value 
            val = ((x.cell(row=1,column=j).value)/15) - 1
            if i - val >= 2:
                end += x.cell(row =i-val,column=j).value
            else:
                end += 0
            
            if i-val+1 < 2:
                if i == 2:
                    cont += 0
                else:
                    for k in range(2,i):
                        cont += x.cell(row=k,column=j).value
            else:
                if i == 2:
                    cont += 0
                else:
                    for k in range(int(i-val+1),i):
                        cont += x.cell(row=k,column=j).value
    
        if (strt + end + cont) <= 3*nurses.cell(row = i, column = 2).value:
            vln_1 += 0
        else:
            vln_1 += 1
        if strt + end <= nurses.cell(row = i, column = 2).value:
            vln_2 += 0
        else:
            vln_2 += 1
    
        total_vln1 += vln_1
        total_vln2 += vln_2
        

    count+= 1        
    
    sheet.cell(row= count, column =2).value = total_vln1  
    sheet.cell(row= count, column =3).value = total_vln2

#CHANGE LATER######################################################################

directory_in_str = "/content/drive/MyDrive/GOOGLE_COLAB/MAYO/OVERRIDE_CODES/org"

#CHANGE LATER######################################################################
    
directory = os.fsencode(directory_in_str)
    
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".txt"):
        new = open(filename,'r')
        new = new.readlines()
        sum = 0
        for i in range(0,3):
            sum += int(new[i].split()[-1])
        for o in range(1,len(patients.worksheets)+1):
            if os.path.splitext(filename)[0] == str(o):
                sheet.cell(row= o+1, column = 4).value = sum
        print(filename, sum)    
   

final.save("/content/drive/MyDrive/GOOGLE_COLAB/MAYO/OVERRIDE_CODES/org std={} analysis.xlsx".format(no_std))
# Out:
# 1.txt 0
# 2.txt 0
# 3.txt 0
# 4.txt 2
# 5.txt 0
# 6.txt 0
# 7.txt 0
# 8.txt 1
# 9.txt 2
# 10.txt 0
# 11.txt 2
# 12.txt 1
# 13.txt 5
# 14.txt 1
# 15.txt 6
# 16.txt 1
# 17.txt 0
# 18.txt 0
# 19.txt 0
# 20.txt 0
# 21.txt 0
# 22.txt 0
